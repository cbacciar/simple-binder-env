# %%
import pyspark
import pandas as pd

# line1's data is located in local directory as a txt file
fnames1  = 'names1.txt'          
# fnames2's data is located in local directory as a csv file
fnames2 = 'names2.csv'

# Task: 
# Print a table view of the full first_name strings found across the combined (2) datasources 
# and their accumulative occurrence count, decending order



# output:
#
#   | first_name      |   count   |
#   | John            |     15    |
#   | Sara            |     12    |
#   | Amar            |      4    |
